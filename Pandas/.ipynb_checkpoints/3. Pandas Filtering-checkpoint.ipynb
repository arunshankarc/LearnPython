# %% [markdown]
# import pandas as pd
# import numpy as np

# %% [markdown]
# # Filter data

# %%
names = ["age","workclass","fnlwgt","education","edu-num","marital-status","occupation","relationship","race","sex","cap-gain","cap-loss","hour/week","country","salary"]
df = pd.read_csv('C:/Personel/LearnPython/code/adult.data.csv', header=None, names=names)
df
# Out:
#        age          workclass  fnlwgt    education  edu-num  \
# 0       39          State-gov   77516    Bachelors       13
# 1       50   Self-emp-not-inc   83311    Bachelors       13
# 2       38            Private  215646      HS-grad        9
# 3       53            Private  234721         11th        7
# 4       28            Private  338409    Bachelors       13
# ...    ...                ...     ...          ...      ...
# 32556   27            Private  257302   Assoc-acdm       12
# 32557   40            Private  154374      HS-grad        9
# 32558   58            Private  151910      HS-grad        9
# 32559   22            Private  201490      HS-grad        9
# 32560   52       Self-emp-inc  287927      HS-grad        9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
# sex column has leading spaces
df['sex'] = df['sex'].apply(lambda x: x.strip())
df.head()
# Out:
#    age          workclass  fnlwgt   education  edu-num       marital-status  \
# 0   39          State-gov   77516   Bachelors       13        Never-married
# 1   50   Self-emp-not-inc   83311   Bachelors       13   Married-civ-spouse
# 2   38            Private  215646     HS-grad        9             Divorced
# 3   53            Private  234721        11th        7   Married-civ-spouse
# 4   28            Private  338409   Bachelors       13   Married-civ-spouse
#
#            occupation    relationship    race     sex  cap-gain  cap-loss  \
# 0        Adm-clerical   Not-in-family   White    Male      2174         0
# 1     Exec-managerial         Husband   White    Male         0         0
# 2   Handlers-cleaners   Not-in-family   White    Male         0         0
# 3   Handlers-cleaners         Husband   Black    Male         0         0
# 4      Prof-specialty            Wife   Black  Female         0         0
#
#    hour/week         country  salary
# ...

# %%
# condition is a series object and when we do df[condition] we only get values which returned as True
condition = df['sex'] == 'Male'
df[condition]
# Out:
#        age          workclass  fnlwgt      education  edu-num  \
# 0       39          State-gov   77516      Bachelors       13
# 1       50   Self-emp-not-inc   83311      Bachelors       13
# 2       38            Private  215646        HS-grad        9
# 3       53            Private  234721           11th        7
# 7       52   Self-emp-not-inc  209642        HS-grad        9
# ...    ...                ...     ...            ...      ...
# 32553   32            Private  116138        Masters       14
# 32554   53            Private  321865        Masters       14
# 32555   22            Private  310152   Some-college       10
# 32557   40            Private  154374        HS-grad        9
# 32559   22            Private  201490        HS-grad        9
#
#             marital-status          occupation    relationship  \
# 0            Never-married        Adm-clerical   Not-in-family
# 1       Married-civ-spouse     Exec-managerial         Husband
# ...

# %%
# Simple way is as below

male_data_df = df[df['sex'] == 'Male']
male_data_df.head()
# Out:
#    age          workclass  fnlwgt   education  edu-num       marital-status  \
# 0   39          State-gov   77516   Bachelors       13        Never-married
# 1   50   Self-emp-not-inc   83311   Bachelors       13   Married-civ-spouse
# 2   38            Private  215646     HS-grad        9             Divorced
# 3   53            Private  234721        11th        7   Married-civ-spouse
# 7   52   Self-emp-not-inc  209642     HS-grad        9   Married-civ-spouse
#
#            occupation    relationship    race   sex  cap-gain  cap-loss  \
# 0        Adm-clerical   Not-in-family   White  Male      2174         0
# 1     Exec-managerial         Husband   White  Male         0         0
# 2   Handlers-cleaners   Not-in-family   White  Male         0         0
# 3   Handlers-cleaners         Husband   Black  Male         0         0
# 7     Exec-managerial         Husband   White  Male         0         0
#
#    hour/week         country  salary
# 0         40   United-States   <=50K
# ...

# %%
# Check age greater than 50 years

age_greater_than_50_years_df= df[df['age'] >= 50]
age_greater_than_50_years_df
# Out:
#        age          workclass  fnlwgt     education  edu-num  \
# 1       50   Self-emp-not-inc   83311     Bachelors       13
# 3       53            Private  234721          11th        7
# 7       52   Self-emp-not-inc  209642       HS-grad        9
# 21      54            Private  302146       HS-grad        9
# 24      59            Private  109015       HS-grad        9
# ...    ...                ...     ...           ...      ...
# 32542   72                  ?  129912       HS-grad        9
# 32548   65   Self-emp-not-inc   99359   Prof-school       15
# 32554   53            Private  321865       Masters       14
# 32558   58            Private  151910       HS-grad        9
# 32560   52       Self-emp-inc  287927       HS-grad        9
#
#             marital-status          occupation    relationship    race  \
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# ...

# %% [markdown]
# # Merge multiple conditions and filter

# %%
# Do not forget to add '()' for each conditions else it will fail with TypeError
male_age_greater_than_50_df = df[(df['sex'] == 'Male') & (df['age'] >= 50)]
male_age_greater_than_50_df
# Out:
#        age          workclass  fnlwgt      education  edu-num  \
# 1       50   Self-emp-not-inc   83311      Bachelors       13
# 3       53            Private  234721           11th        7
# 7       52   Self-emp-not-inc  209642        HS-grad        9
# 25      56          Local-gov  216851      Bachelors       13
# 27      54                  ?  180211   Some-college       10
# ...    ...                ...     ...            ...      ...
# 32533   54            Private  337992      Bachelors       13
# 32539   71                  ?  287372      Doctorate       16
# 32542   72                  ?  129912        HS-grad        9
# 32548   65   Self-emp-not-inc   99359    Prof-school       15
# 32554   53            Private  321865        Masters       14
#
#             marital-status          occupation    relationship  \
# 1       Married-civ-spouse     Exec-managerial         Husband
# 3       Married-civ-spouse   Handlers-cleaners         Husband
# ...

# %% [markdown]
# # .isin()

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  edu-num       marital-status  \
# 0   39          State-gov   77516   Bachelors       13        Never-married
# 1   50   Self-emp-not-inc   83311   Bachelors       13   Married-civ-spouse
# 2   38            Private  215646     HS-grad        9             Divorced
# 3   53            Private  234721        11th        7   Married-civ-spouse
# 4   28            Private  338409   Bachelors       13   Married-civ-spouse
#
#            occupation    relationship    race     sex  cap-gain  cap-loss  \
# 0        Adm-clerical   Not-in-family   White    Male      2174         0
# 1     Exec-managerial         Husband   White    Male         0         0
# 2   Handlers-cleaners   Not-in-family   White    Male         0         0
# 3   Handlers-cleaners         Husband   Black    Male         0         0
# 4      Prof-specialty            Wife   Black  Female         0         0
#
#    hour/week         country  salary
# ...

# %%
# If you want to find unique values present for a column, use below 

len(df['education'].unique())
# Out:
# 16

# %% [markdown]
# ### Lets say I want to filter data in such a way that for a given column I need to check for multiple conditions, then in previous way I will have to add multiple conditions which is cumbersome, so in simple terms just use isin()
# ### For example education should be 10th, 11th, 12th, Bachelors, Masters

# %%
df['education'] = df['education'].apply(lambda x: x.strip())
df[df['education'].isin(['10th', '11th', '12th', 'Bachelors', 'Master'])]
# Out:
#        age          workclass  fnlwgt  education  edu-num  \
# 0       39          State-gov   77516  Bachelors       13
# 1       50   Self-emp-not-inc   83311  Bachelors       13
# 3       53            Private  234721       11th        7
# 4       28            Private  338409  Bachelors       13
# 9       42            Private  159449  Bachelors       13
# ...    ...                ...     ...        ...      ...
# 32533   54            Private  337992  Bachelors       13
# 32535   22            Private  325033       12th        8
# 32536   34            Private  160216  Bachelors       13
# 32538   38            Private  139180  Bachelors       13
# 32551   32            Private   34066       10th        6
#
#             marital-status          occupation    relationship  \
# 0            Never-married        Adm-clerical   Not-in-family
# 1       Married-civ-spouse     Exec-managerial         Husband
# 3       Married-civ-spouse   Handlers-cleaners         Husband
# ...

# %% [markdown]
# # between()

# %%
age_between_59_60_years = df[df['age'].between(59, 60)]

# %%
age_between_59_60_years.head()
# Out:
#      age   workclass  fnlwgt education  edu-num       marital-status  \
# 24    59     Private  109015   HS-grad        9             Divorced
# 83    59     Private  159937   HS-grad        9   Married-civ-spouse
# 213   60     Private   85815   HS-grad        9   Married-civ-spouse
# 226   60           ?   24215      10th        6             Divorced
# 235   59   State-gov  268700   HS-grad        9   Married-civ-spouse
#
#          occupation    relationship                 race     sex  cap-gain  \
# 24     Tech-support       Unmarried                White  Female         0
# 83            Sales         Husband                White    Male         0
# 213    Craft-repair         Husband   Asian-Pac-Islander    Male         0
# 226               ?   Not-in-family   Amer-Indian-Eskimo  Female         0
# 235   Other-service         Husband                White    Male         0
#
#      cap-loss  hour/week         country  salary
# 24          0         40   United-States   <=50K
# ...

# %% [markdown]
# # nunique() and unique()

# %%
df.head()
# Out:
#    age          workclass  fnlwgt  education  edu-num       marital-status  \
# 0   39          State-gov   77516  Bachelors       13        Never-married
# 1   50   Self-emp-not-inc   83311  Bachelors       13   Married-civ-spouse
# 2   38            Private  215646    HS-grad        9             Divorced
# 3   53            Private  234721       11th        7   Married-civ-spouse
# 4   28            Private  338409  Bachelors       13   Married-civ-spouse
#
#            occupation    relationship    race     sex  cap-gain  cap-loss  \
# 0        Adm-clerical   Not-in-family   White    Male      2174         0
# 1     Exec-managerial         Husband   White    Male         0         0
# 2   Handlers-cleaners   Not-in-family   White    Male         0         0
# 3   Handlers-cleaners         Husband   Black    Male         0         0
# 4      Prof-specialty            Wife   Black  Female         0         0
#
#    hour/week         country  salary
# ...

# %%
df['sex'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df['sex'].nunique() # This gets the number of unique values count
# Out:
# 2

# %%
df['relationship'].nunique()
# Out:
# 6
